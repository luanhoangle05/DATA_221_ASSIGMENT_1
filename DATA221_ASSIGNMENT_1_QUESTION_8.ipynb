# %%
import pandas as pd
data = {
"A": [1, 2, 2, 1],
"B": [3.1, 4.2, 1.5, 6.3],
"C": [800, 150, 400, 210]
}
df=pd.DataFrame(data)
# compute D=A*B
df["D"]=df["A"]*df["B"]
print(df)
# Out:
#    A    B    C    D
# 0  1  3.1  800  3.1
# 1  2  4.2  150  8.4
# 2  2  1.5  400  3.0
# 3  1  6.3  210  6.3

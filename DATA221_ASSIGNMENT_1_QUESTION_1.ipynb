# %%
thresholdValue=100
current_product=1
current_multiplier=1
while current_product<=thresholdValue:
    current_multiplier+=1
    current_product=current_product*current_multiplier
print("Final product: ",current_product)
print("Integer that exceed threshold: ",current_multiplier)
# Out:
# 120
# 5
